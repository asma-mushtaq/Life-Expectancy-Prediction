# %% [markdown]
# ## INTRODUCTION
# This dataset comprises 204 entries and 38 attributes, providing a comprehensive analysis of key economic and social indicators across various countries. It includes a diverse range of metrics, allowing for in-depth exploration of global trends related to GDP, education, health, and environmental factors.
#
# ### KEY FEATURES
#
# **GDP**: Gross Domestic Product (in current US dollars), representing the total economic output of a country.<br>
# **Sex Ratio**: The ratio of males to females in the population, highlighting demographic trends.<br>
# **Life Expectancy**: Average lifespan for males and females, an essential indicator of healthcare quality.<br>
# **Education Enrollment Rates**: Data on primary, secondary, and post-secondary education enrollment for males and females, reflecting educational attainment.<br>
# **Unemployment Rate**: Percentage of the labor force that is unemployed, indicating economic health.<br>
# **Homicide Rate**: Number of homicides per 100,000 population, providing insight into safety and crime levels.<br>
# **Urban Population Growth**: Rate of growth in urban populations, illustrating migration trends.<br>
# **CO2 Emissions**: Carbon dioxide emissions per capita, an important measure of environmental impact.<br>
# **Forested Area**: Percentage of land covered by forests, indicating biodiversity and environmental health.<br>
# **Tourist Numbers**: Total number of international visitors, which can reflect a country's tourism potential.

# %%
# import essential libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('country_data.csv')

# %%
data.shape
# Out:
# (204, 38)

# %%
data.head()
# Out:
#         gdp  sex_ratio  surface_area  life_expectancy_male  unemployment  \
# 0   20514.0      105.4      652864.0                  62.8          11.2
# 1   15059.0      103.7       28748.0                  76.7          12.8
# 2  173757.0      102.1     2381741.0                  75.4          11.5
# 3    3238.0      102.3         468.0                   NaN           NaN
# 4  105902.0       97.9     1246700.0                  57.8           6.8
#
#    imports  homicide_rate                                   currency iso2  \
# 0   8370.0            6.7         {'code': 'AFN', 'name': 'Afghani'}   AF
# 1   5908.0            2.3             {'code': 'ALL', 'name': 'Lek'}   AL
# 2  45140.0            1.4  {'code': 'DZD', 'name': 'Algerian Dinar'}   DZ
# 3   1538.0            0.0            {'code': 'EUR', 'name': 'Euro'}   AD
# 4  21340.0            4.8          {'code': 'AOA', 'name': 'Kwanza'}   AO
#
#    employment_services  ...  pop_growth           region  pop_density  \
# 0                 39.4  ...         2.5    Southern Asia         59.6
# 1                 43.7  ...        -0.1  Southern Europe        105.0
# 2                 59.6  ...         2.0  Northern Africa         18.4
# 3                  NaN  ...        -0.2  Southern Europe        164.2
# 4                 41.7  ...         3.3    Middle Africa         26.4
#
#    internet_users gdp_per_capita  fertility  refugees  \
# 0            13.5          551.9        4.6    2826.4
# 1            71.8         5223.8        1.6       4.3
# 2            49.0         4114.7        3.0      99.5
# 3            91.6        42051.6        1.2       NaN
# 4            14.3         3437.3        5.6      70.1
#
#    primary_school_enrollment_male  co2_emissions  tourists
# 0                           124.2            NaN       NaN
# 1                           105.2            4.3    5340.0
# 2                           112.4          130.5    2657.0
# 3                             NaN            NaN    3042.0
# 4                           121.1           18.0     218.0
#
# [5 rows x 38 columns]

# %%
# There seem to be a few number of missing values in almost all the columns. Needs a better understanding
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gdp                                 203 non-null    float64
#  1   sex_ratio                           204 non-null    float64
#  2   surface_area                        203 non-null    float64
#  3   life_expectancy_male                198 non-null    float64
#  4   unemployment                        194 non-null    float64
#  5   imports                             199 non-null    float64
#  6   homicide_rate                       181 non-null    float64
#  7   currency                            204 non-null    object
#  8   iso2                                203 non-null    object
#  9   employment_services                 193 non-null    float64
#  10  employment_industry                 193 non-null    float64
#  11  urban_population_growth             204 non-null    float64
#  12  secondary_school_enrollment_female  190 non-null    float64
#  13  employment_agriculture              193 non-null    float64
#  14  capital                             204 non-null    object
#  15  forested_area                       200 non-null    float64
#  16  exports                             199 non-null    float64
#  17  life_expectancy_female              198 non-null    float64
#  18  post_secondary_enrollment_female    171 non-null    float64
#  19  post_secondary_enrollment_male      171 non-null    float64
#  20  primary_school_enrollment_female    196 non-null    float64
#  21  infant_mortality                    196 non-null    float64
#  22  gdp_growth                          203 non-null    float64
#  23  threatened_species                  204 non-null    float64
#  24  population                          204 non-null    float64
#  25  urban_population                    204 non-null    float64
#  26  secondary_school_enrollment_male    190 non-null    float64
#  27  name                                204 non-null    object
#  28  pop_growth                          204 non-null    float64
#  29  region                              204 non-null    object
#  30  pop_density                         204 non-null    float64
#  31  internet_users                      202 non-null    float64
#  32  gdp_per_capita                      203 non-null    float64
#  33  fertility                           199 non-null    float64
#  34  refugees                            190 non-null    float64
#  35  primary_school_enrollment_male      196 non-null    float64
#  36  co2_emissions                       145 non-null    float64
#  37  tourists                            194 non-null    float64
# dtypes: float64(33), object(5)
# memory usage: 60.7+ KB

# %%
# Finding missing data count/percenatge of missing values
missing = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing.columns=['Count', 'Percentage']
missing.sort_values(by='Count', ascending = False)
# Out:
#                                     Count  Percentage
# co2_emissions                          59   28.921569
# post_secondary_enrollment_male         33   16.176471
# post_secondary_enrollment_female       33   16.176471
# homicide_rate                          23   11.274510
# refugees                               14    6.862745
# secondary_school_enrollment_male       14    6.862745
# secondary_school_enrollment_female     14    6.862745
# employment_industry                    11    5.392157
# employment_agriculture                 11    5.392157
# employment_services                    11    5.392157
# tourists                               10    4.901961
# unemployment                           10    4.901961
# primary_school_enrollment_female        8    3.921569
# primary_school_enrollment_male          8    3.921569
# infant_mortality                        8    3.921569
# life_expectancy_female                  6    2.941176
# life_expectancy_male                    6    2.941176
# exports                                 5    2.450980
# imports                                 5    2.450980
# fertility                               5    2.450980
# forested_area                           4    1.960784
# internet_users                          2    0.980392
# iso2                                    1    0.490196
# gdp_per_capita                          1    0.490196
# gdp                                     1    0.490196
# gdp_growth                              1    0.490196
# surface_area                            1    0.490196
# region                                  0    0.000000
# pop_density                             0    0.000000
# urban_population_growth                 0    0.000000
# pop_growth                              0    0.000000
# name                                    0    0.000000
# urban_population                        0    0.000000
# threatened_species                      0    0.000000
# sex_ratio                               0    0.000000
# capital                                 0    0.000000
# currency                                0    0.000000
# population                              0    0.000000

# %%
# I would like to reshuffle some columns. Bringing the country code, captial and region to the left most side
# Just for the visual ease

new_column_order = ['iso2','name','capital','region','currency','gdp','gdp_per_capita','gdp_growth','life_expectancy_female',
                    'life_expectancy_male','fertility','infant_mortality','sex_ratio', 'population','pop_growth', 
                    'pop_density','urban_population','urban_population_growth','imports','exports','unemployment',
                    'employment_industry','employment_agriculture','employment_services','tourists','surface_area',
                    'forested_area','internet_users','homicide_rate','refugees','threatened_species','primary_school_enrollment_female',
                    'primary_school_enrollment_male','secondary_school_enrollment_female','secondary_school_enrollment_male', 
                    'post_secondary_enrollment_female', 'post_secondary_enrollment_male','co2_emissions']
data = data[new_column_order]

# %%
# My assumption here is that the rows with just 1 value missing might be a single row. So let us check that.
# Partially right, Row 198 has 'gdp_per_capita', 'gdp', 'gdp_growth' missing. Additionally it has more features missing as well.
# 131: ios2 missing
# 175: Surface area missing, but rest are important.
# 198: 

data[data[['iso2','gdp_per_capita', 'gdp', 'gdp_growth', 'surface_area' ]].isnull().any(axis = 1)]
# Out:
#     iso2                           name       capital           region  \
# 131  NaN                        Namibia      Windhoek  Southern Africa
# 175   SD                          Sudan      Khartoum  Northern Africa
# 198   VA  Holy See (Vatican City State)  Vatican City  Southern Europe
#
#                                       currency      gdp  gdp_per_capita  \
# 131  {'code': 'NAD', 'name': 'Namibia Dollar'}  14519.0          5930.1
# 175  {'code': 'SDG', 'name': 'Sudanese Pound'}  50515.0          1208.4
# 198            {'code': 'EUR', 'name': 'Euro'}      NaN             NaN
#
#      gdp_growth  life_expectancy_female  life_expectancy_male  ...  \
# 131        -0.1                    65.8                  60.0  ...
# 175        -2.3                    66.8                  63.1  ...
# 198         NaN                     NaN                   NaN  ...
#
#      homicide_rate  refugees  threatened_species  \
# 131           17.7       4.3               117.0
# 175            5.1    2974.1               158.0
# 198            0.0       NaN                 1.0
#
#      primary_school_enrollment_female  primary_school_enrollment_male  \
# 131                             122.1                           126.4
# 175                              74.4                            79.2
# 198                               NaN                             NaN
#
#      secondary_school_enrollment_female  secondary_school_enrollment_male  \
# 131                                70.0                              61.5
# 175                                47.0                              46.3
# 198                                 NaN                               NaN
#
#      post_secondary_enrollment_female  post_secondary_enrollment_male  \
# 131                              30.3                            15.3
# 175                              17.1                            16.8
# 198                               NaN                             NaN
#
#      co2_emissions
# 131            4.0
# 175           18.8
# 198            NaN
#
# [3 rows x 38 columns]

# %%
# Looking at row 198 in complete as it seems most of the columns are missing, so that whether to drop this rpw
# can be decided. Looks like we can drop it.

data.iloc[198,:]
# Out:
# iso2                                                               VA
# name                                    Holy See (Vatican City State)
# capital                                                  Vatican City
# region                                                Southern Europe
# currency                              {'code': 'EUR', 'name': 'Euro'}
# gdp                                                               NaN
# gdp_per_capita                                                    NaN
# gdp_growth                                                        NaN
# life_expectancy_female                                            NaN
# life_expectancy_male                                              NaN
# fertility                                                         NaN
# infant_mortality                                                  NaN
# sex_ratio                                                       219.2
# population                                                        1.0
# pop_growth                                                        0.1
# pop_density                                                    1820.5
# urban_population                                                100.0
# urban_population_growth                                           0.2
# imports                                                           NaN
# exports                                                           NaN
# unemployment                                                      NaN
# employment_industry                                               NaN
# employment_agriculture                                            NaN
# employment_services                                               NaN
# tourists                                                          NaN
# surface_area                                                      0.0
# forested_area                                                     NaN
# internet_users                                                    NaN
# homicide_rate                                                     0.0
# refugees                                                          NaN
# threatened_species                                                1.0
# primary_school_enrollment_female                                  NaN
# primary_school_enrollment_male                                    NaN
# secondary_school_enrollment_female                                NaN
# secondary_school_enrollment_male                                  NaN
# post_secondary_enrollment_female                                  NaN
# post_secondary_enrollment_male                                    NaN
# co2_emissions                                                     NaN
# Name: 198, dtype: object

# %%
# looking closely at the regions
data['region'].unique()
# Out:
# array(['Southern Asia', 'Southern Europe', 'Northern Africa',
#        'Middle Africa', 'Caribbean', 'South America', 'Western Asia',
#        'Oceania', 'Western Europe', 'Eastern Europe', 'Central America',
#        'Western Africa', 'Southern Africa', 'South-Eastern Asia',
#        'Eastern Africa', 'Northern America', 'Eastern Asia',
#        'Northern Europe', 'Melanesia', 'Central Asia', 'Micronesia',
#        'Polynesia'], dtype=object)

# %%
# Looking at the contry code, name and capital, we can keep just one (name in my opinion) as the other info is 
# redundunt
print(len(data['region'].unique()))
print(len(data['iso2'].unique()))
print(len(data['name'].unique()))
print(len(data['capital'].unique()))
# Out:
# 22
# 192
# 192
# 192

# %%
# Seeing that the regions are repeated, iso2 codes might be too, code to find the rows with same iso2 code:
group_iso = data.groupby('iso2').filter(lambda x: len(x)>1)
group_iso
# Out:
#     iso2                 name           capital           region  \
# 0     AF          Afghanistan             Kabul    Southern Asia
# 1     AL              Albania            Tirana  Southern Europe
# 2     DZ              Algeria           Algiers  Northern Africa
# 3     AD              Andorra  Andorra La Vella  Southern Europe
# 4     AO               Angola            Luanda    Middle Africa
# 5     AG  Antigua And Barbuda      Saint John's        Caribbean
# 6     AR            Argentina      Buenos Aires    South America
# 7     AM              Armenia           Yerevan     Western Asia
# 8     AU            Australia          Canberra          Oceania
# 9     AT              Austria            Vienna   Western Europe
# 10    AF          Afghanistan             Kabul    Southern Asia
# 11    AL              Albania            Tirana  Southern Europe
# 12    DZ              Algeria           Algiers  Northern Africa
# 13    AD              Andorra  Andorra La Vella  Southern Europe
# 14    AO               Angola            Luanda    Middle Africa
# 15    AG  Antigua And Barbuda      Saint John's        Caribbean
# 16    AR            Argentina      Buenos Aires    South America
# 17    AM              Armenia           Yerevan     Western Asia
# 18    AU            Australia          Canberra          Oceania
# 19    AT              Austria            Vienna   Western Europe
# 70    FR               France             Paris   Western Europe
# 121   TR               Turkey            Ankara     Western Asia
# 140   FR               France             Paris   Western Europe
# 187   TR               Turkey            Ankara     Western Asia
#
#                                            currency        gdp  \
# 0                {'code': 'AFN', 'name': 'Afghani'}    20514.0
# 1                    {'code': 'ALL', 'name': 'Lek'}    15059.0
# 2         {'code': 'DZD', 'name': 'Algerian Dinar'}   173757.0
# 3                   {'code': 'EUR', 'name': 'Euro'}     3238.0
# 4                 {'code': 'AOA', 'name': 'Kwanza'}   105902.0
# 5    {'code': 'XCD', 'name': 'E. Caribbean Dollar'}     1611.0
# 6         {'code': 'ARS', 'name': 'Argentine Peso'}   518475.0
# 7          {'code': 'AMD', 'name': 'Armenian Dram'}    12433.0
# 8      {'code': 'AUD', 'name': 'Australian Dollar'}  1453871.0
# 9                   {'code': 'EUR', 'name': 'Euro'}   455508.0
# 10               {'code': 'AFN', 'name': 'Afghani'}    20514.0
# 11                   {'code': 'ALL', 'name': 'Lek'}    15059.0
# 12        {'code': 'DZD', 'name': 'Algerian Dinar'}   173757.0
# 13                  {'code': 'EUR', 'name': 'Euro'}     3238.0
# 14                {'code': 'AOA', 'name': 'Kwanza'}   105902.0
# 15   {'code': 'XCD', 'name': 'E. Caribbean Dollar'}     1611.0
# 16        {'code': 'ARS', 'name': 'Argentine Peso'}   518475.0
# 17         {'code': 'AMD', 'name': 'Armenian Dram'}    12433.0
# 18     {'code': 'AUD', 'name': 'Australian Dollar'}  1453871.0
# 19                  {'code': 'EUR', 'name': 'Euro'}   455508.0
# 70                  {'code': 'EUR', 'name': 'Euro'}  2778892.0
# 121         {'code': 'TRY', 'name': 'Turkish Lira'}   771355.0
# 140                 {'code': 'EUR', 'name': 'Euro'}  2778892.0
# 187         {'code': 'TRY', 'name': 'Turkish Lira'}   771355.0
#
#      gdp_per_capita  gdp_growth  life_expectancy_female  life_expectancy_male  \
# 0             551.9        -1.7                    65.8                  62.8
# 1            5223.8         4.1                    80.1                  76.7
# 2            4114.7         1.4                    77.8                  75.4
# 3           42051.6         1.6                     NaN                   NaN
# 4            3437.3        -1.2                    63.4                  57.8
# 5           16727.0         7.4                    77.9                  75.7
# 6           11687.6        -2.5                    79.8                  73.0
# 7            4212.1         5.2                    78.3                  71.1
# 8           58392.7         2.0                    85.2                  81.2
# 9           51230.3         2.4                    83.8                  78.9
# 10            551.9        -1.7                    65.8                  62.8
# 11           5223.8         4.1                    80.1                  76.7
# 12           4114.7         1.4                    77.8                  75.4
# 13          42051.6         1.6                     NaN                   NaN
# 14           3437.3        -1.2                    63.4                  57.8
# 15          16727.0         7.4                    77.9                  75.7
# 16          11687.6        -2.5                    79.8                  73.0
# 17           4212.1         5.2                    78.3                  71.1
# 18          58392.7         2.0                    85.2                  81.2
# 19          51230.3         2.4                    83.8                  78.9
# 70          41358.1         1.7                    85.4                  79.4
# 121          9367.9         2.8                    80.2                  74.3
# 140         41358.1         1.7                    85.4                  79.4
# 187          9367.9         2.8                    80.2                  74.3
#
#      ...  homicide_rate  refugees  threatened_species  \
# 0    ...            6.7    2826.4                40.0
# 1    ...            2.3       4.3               142.0
# 2    ...            1.4      99.5               155.0
# 3    ...            0.0       NaN                15.0
# 4    ...            4.8      70.1               171.0
# 5    ...           11.1       0.2                61.0
# 6    ...            5.3     165.6               285.0
# 7    ...            1.7      19.0               119.0
# 8    ...            0.9     129.2              1308.0
# 9    ...            1.0     163.7               185.0
# 10   ...            6.7    2826.4                40.0
# 11   ...            2.3       4.3               142.0
# 12   ...            1.4      99.5               155.0
# 13   ...            0.0       NaN                15.0
# 14   ...            4.8      70.1               171.0
# 15   ...           11.1       0.2                61.0
# 16   ...            5.3     165.6               285.0
# 17   ...            1.7      19.0               119.0
# 18   ...            0.9     129.2              1308.0
# 19   ...            1.0     163.7               185.0
# 70   ...            1.2     473.4               366.0
# 121  ...            2.6    3940.1               435.0
# 140  ...            1.2     473.4               366.0
# 187  ...            2.6    3940.1               435.0
#
#      primary_school_enrollment_female  primary_school_enrollment_male  \
# 0                                82.9                           124.2
# 1                               109.1                           105.2
# 2                               107.3                           112.4
# 3                                 NaN                             NaN
# 4                               105.9                           121.1
# 5                               104.6                           105.4
# 6                               109.6                           109.9
# 7                                92.7                            92.7
# 8                               100.3                           100.3
# 9                               103.0                           103.2
# 10                               82.9                           124.2
# 11                              109.1                           105.2
# 12                              107.3                           112.4
# 13                                NaN                             NaN
# 14                              105.9                           121.1
# 15                              104.6                           105.4
# 16                              109.6                           109.9
# 17                               92.7                            92.7
# 18                              100.3                           100.3
# 19                              103.0                           103.2
# 70                              102.2                           102.8
# 121                              92.7                            93.6
# 140                             102.2                           102.8
# 187                              92.7                            93.6
#
#      secondary_school_enrollment_female  secondary_school_enrollment_male  \
# 0                                  40.0                              70.1
# 1                                  95.7                              95.2
# 2                                 101.5                              97.8
# 3                                   NaN                               NaN
# 4                                  39.7                              61.8
# 5                                 109.1                             113.3
# 6                                 111.0                             106.5
# 7                                  84.8                              81.7
# 8                                 141.2                             159.0
# 9                                  98.3                             102.5
# 10                                 40.0                              70.1
# 11                                 95.7                              95.2
# 12                                101.5                              97.8
# 13                                  NaN                               NaN
# 14                                 39.7                              61.8
# 15                                109.1                             113.3
# 16                                111.0                             106.5
# 17                                 84.8                              81.7
# 18                                141.2                             159.0
# 19                                 98.3                             102.5
# 70                                104.1                             103.5
# 121                               103.4                             108.5
# 140                               104.1                             103.5
# 187                               103.4                             108.5
#
#      post_secondary_enrollment_female  post_secondary_enrollment_male  \
# 0                                 4.9                            14.2
# 1                                67.6                            43.0
# 2                                64.4                            38.8
# 3                                 NaN                             NaN
# 4                                 8.5                            10.2
# 5                                34.3                            15.3
# 6                               112.8                            67.8
# 7                                62.6                            47.1
# 8                               133.3                            93.8
# 9                                92.5                            78.1
# 10                                4.9                            14.2
# 11                               67.6                            43.0
# 12                               64.4                            38.8
# 13                                NaN                             NaN
# 14                                8.5                            10.2
# 15                               34.3                            15.3
# 16                              112.8                            67.8
# 17                               62.6                            47.1
# 18                              133.3                            93.8
# 19                               92.5                            78.1
# 70                               72.8                            58.7
# 121                               NaN                             NaN
# 140                              72.8                            58.7
# 187                               NaN                             NaN
#
#      co2_emissions
# 0              NaN
# 1              4.3
# 2            130.5
# 3              NaN
# 4             18.0
# 5              NaN
# 6            183.4
# 7              5.2
# 8            384.6
# 9             64.9
# 10             NaN
# 11             4.3
# 12           130.5
# 13             NaN
# 14            18.0
# 15             NaN
# 16           183.4
# 17             5.2
# 18           384.6
# 19            64.9
# 70           306.1
# 121          378.6
# 140          306.1
# 187          378.6
#
# [24 rows x 38 columns]

# %%
# sorting it so that same iso2s are together:
# turns out based on iso2, 12 rows are complete duplicates of other rows. Therefore need to be dropped.

sort_iso = group_iso.sort_values(by = 'iso2')
sort_iso
# Out:
#     iso2                 name           capital           region  \
# 13    AD              Andorra  Andorra La Vella  Southern Europe
# 3     AD              Andorra  Andorra La Vella  Southern Europe
# 0     AF          Afghanistan             Kabul    Southern Asia
# 10    AF          Afghanistan             Kabul    Southern Asia
# 15    AG  Antigua And Barbuda      Saint John's        Caribbean
# 5     AG  Antigua And Barbuda      Saint John's        Caribbean
# 11    AL              Albania            Tirana  Southern Europe
# 1     AL              Albania            Tirana  Southern Europe
# 17    AM              Armenia           Yerevan     Western Asia
# 7     AM              Armenia           Yerevan     Western Asia
# 4     AO               Angola            Luanda    Middle Africa
# 14    AO               Angola            Luanda    Middle Africa
# 6     AR            Argentina      Buenos Aires    South America
# 16    AR            Argentina      Buenos Aires    South America
# 19    AT              Austria            Vienna   Western Europe
# 9     AT              Austria            Vienna   Western Europe
# 8     AU            Australia          Canberra          Oceania
# 18    AU            Australia          Canberra          Oceania
# 12    DZ              Algeria           Algiers  Northern Africa
# 2     DZ              Algeria           Algiers  Northern Africa
# 140   FR               France             Paris   Western Europe
# 70    FR               France             Paris   Western Europe
# 121   TR               Turkey            Ankara     Western Asia
# 187   TR               Turkey            Ankara     Western Asia
#
#                                            currency        gdp  \
# 13                  {'code': 'EUR', 'name': 'Euro'}     3238.0
# 3                   {'code': 'EUR', 'name': 'Euro'}     3238.0
# 0                {'code': 'AFN', 'name': 'Afghani'}    20514.0
# 10               {'code': 'AFN', 'name': 'Afghani'}    20514.0
# 15   {'code': 'XCD', 'name': 'E. Caribbean Dollar'}     1611.0
# 5    {'code': 'XCD', 'name': 'E. Caribbean Dollar'}     1611.0
# 11                   {'code': 'ALL', 'name': 'Lek'}    15059.0
# 1                    {'code': 'ALL', 'name': 'Lek'}    15059.0
# 17         {'code': 'AMD', 'name': 'Armenian Dram'}    12433.0
# 7          {'code': 'AMD', 'name': 'Armenian Dram'}    12433.0
# 4                 {'code': 'AOA', 'name': 'Kwanza'}   105902.0
# 14                {'code': 'AOA', 'name': 'Kwanza'}   105902.0
# 6         {'code': 'ARS', 'name': 'Argentine Peso'}   518475.0
# 16        {'code': 'ARS', 'name': 'Argentine Peso'}   518475.0
# 19                  {'code': 'EUR', 'name': 'Euro'}   455508.0
# 9                   {'code': 'EUR', 'name': 'Euro'}   455508.0
# 8      {'code': 'AUD', 'name': 'Australian Dollar'}  1453871.0
# 18     {'code': 'AUD', 'name': 'Australian Dollar'}  1453871.0
# 12        {'code': 'DZD', 'name': 'Algerian Dinar'}   173757.0
# 2         {'code': 'DZD', 'name': 'Algerian Dinar'}   173757.0
# 140                 {'code': 'EUR', 'name': 'Euro'}  2778892.0
# 70                  {'code': 'EUR', 'name': 'Euro'}  2778892.0
# 121         {'code': 'TRY', 'name': 'Turkish Lira'}   771355.0
# 187         {'code': 'TRY', 'name': 'Turkish Lira'}   771355.0
#
#      gdp_per_capita  gdp_growth  life_expectancy_female  life_expectancy_male  \
# 13          42051.6         1.6                     NaN                   NaN
# 3           42051.6         1.6                     NaN                   NaN
# 0             551.9        -1.7                    65.8                  62.8
# 10            551.9        -1.7                    65.8                  62.8
# 15          16727.0         7.4                    77.9                  75.7
# 5           16727.0         7.4                    77.9                  75.7
# 11           5223.8         4.1                    80.1                  76.7
# 1            5223.8         4.1                    80.1                  76.7
# 17           4212.1         5.2                    78.3                  71.1
# 7            4212.1         5.2                    78.3                  71.1
# 4            3437.3        -1.2                    63.4                  57.8
# 14           3437.3        -1.2                    63.4                  57.8
# 6           11687.6        -2.5                    79.8                  73.0
# 16          11687.6        -2.5                    79.8                  73.0
# 19          51230.3         2.4                    83.8                  78.9
# 9           51230.3         2.4                    83.8                  78.9
# 8           58392.7         2.0                    85.2                  81.2
# 18          58392.7         2.0                    85.2                  81.2
# 12           4114.7         1.4                    77.8                  75.4
# 2            4114.7         1.4                    77.8                  75.4
# 140         41358.1         1.7                    85.4                  79.4
# 70          41358.1         1.7                    85.4                  79.4
# 121          9367.9         2.8                    80.2                  74.3
# 187          9367.9         2.8                    80.2                  74.3
#
#      ...  homicide_rate  refugees  threatened_species  \
# 13   ...            0.0       NaN                15.0
# 3    ...            0.0       NaN                15.0
# 0    ...            6.7    2826.4                40.0
# 10   ...            6.7    2826.4                40.0
# 15   ...           11.1       0.2                61.0
# 5    ...           11.1       0.2                61.0
# 11   ...            2.3       4.3               142.0
# 1    ...            2.3       4.3               142.0
# 17   ...            1.7      19.0               119.0
# 7    ...            1.7      19.0               119.0
# 4    ...            4.8      70.1               171.0
# 14   ...            4.8      70.1               171.0
# 6    ...            5.3     165.6               285.0
# 16   ...            5.3     165.6               285.0
# 19   ...            1.0     163.7               185.0
# 9    ...            1.0     163.7               185.0
# 8    ...            0.9     129.2              1308.0
# 18   ...            0.9     129.2              1308.0
# 12   ...            1.4      99.5               155.0
# 2    ...            1.4      99.5               155.0
# 140  ...            1.2     473.4               366.0
# 70   ...            1.2     473.4               366.0
# 121  ...            2.6    3940.1               435.0
# 187  ...            2.6    3940.1               435.0
#
#      primary_school_enrollment_female  primary_school_enrollment_male  \
# 13                                NaN                             NaN
# 3                                 NaN                             NaN
# 0                                82.9                           124.2
# 10                               82.9                           124.2
# 15                              104.6                           105.4
# 5                               104.6                           105.4
# 11                              109.1                           105.2
# 1                               109.1                           105.2
# 17                               92.7                            92.7
# 7                                92.7                            92.7
# 4                               105.9                           121.1
# 14                              105.9                           121.1
# 6                               109.6                           109.9
# 16                              109.6                           109.9
# 19                              103.0                           103.2
# 9                               103.0                           103.2
# 8                               100.3                           100.3
# 18                              100.3                           100.3
# 12                              107.3                           112.4
# 2                               107.3                           112.4
# 140                             102.2                           102.8
# 70                              102.2                           102.8
# 121                              92.7                            93.6
# 187                              92.7                            93.6
#
#      secondary_school_enrollment_female  secondary_school_enrollment_male  \
# 13                                  NaN                               NaN
# 3                                   NaN                               NaN
# 0                                  40.0                              70.1
# 10                                 40.0                              70.1
# 15                                109.1                             113.3
# 5                                 109.1                             113.3
# 11                                 95.7                              95.2
# 1                                  95.7                              95.2
# 17                                 84.8                              81.7
# 7                                  84.8                              81.7
# 4                                  39.7                              61.8
# 14                                 39.7                              61.8
# 6                                 111.0                             106.5
# 16                                111.0                             106.5
# 19                                 98.3                             102.5
# 9                                  98.3                             102.5
# 8                                 141.2                             159.0
# 18                                141.2                             159.0
# 12                                101.5                              97.8
# 2                                 101.5                              97.8
# 140                               104.1                             103.5
# 70                                104.1                             103.5
# 121                               103.4                             108.5
# 187                               103.4                             108.5
#
#      post_secondary_enrollment_female  post_secondary_enrollment_male  \
# 13                                NaN                             NaN
# 3                                 NaN                             NaN
# 0                                 4.9                            14.2
# 10                                4.9                            14.2
# 15                               34.3                            15.3
# 5                                34.3                            15.3
# 11                               67.6                            43.0
# 1                                67.6                            43.0
# 17                               62.6                            47.1
# 7                                62.6                            47.1
# 4                                 8.5                            10.2
# 14                                8.5                            10.2
# 6                               112.8                            67.8
# 16                              112.8                            67.8
# 19                               92.5                            78.1
# 9                                92.5                            78.1
# 8                               133.3                            93.8
# 18                              133.3                            93.8
# 12                               64.4                            38.8
# 2                                64.4                            38.8
# 140                              72.8                            58.7
# 70                               72.8                            58.7
# 121                               NaN                             NaN
# 187                               NaN                             NaN
#
#      co2_emissions
# 13             NaN
# 3              NaN
# 0              NaN
# 10             NaN
# 15             NaN
# 5              NaN
# 11             4.3
# 1              4.3
# 17             5.2
# 7              5.2
# 4             18.0
# 14            18.0
# 6            183.4
# 16           183.4
# 19            64.9
# 9             64.9
# 8            384.6
# 18           384.6
# 12           130.5
# 2            130.5
# 140          306.1
# 70           306.1
# 121          378.6
# 187          378.6
#
# [24 rows x 38 columns]

# %%
# dropping the duplicates as the ones with same iso2 codes have all the other columns same as well

data.drop_duplicates(inplace=True)

# %%
# rows were 204 earlier, dropped 12 duplicates and the 198th row with most rows missing
data.drop(index=198, inplace=True)
data.shape
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### After droping duplicates (12 in total) and the one row with most of the values missing, we are left with 191 rows and 38 columns to work with

# %%
# again checking for missing data
missing2 = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing2.columns=['Count', 'Percentage']
missing2.sort_values(by='Count', ascending = False)
# Out:
#                                     Count  Percentage
# co2_emissions                          55   28.795812
# post_secondary_enrollment_male         30   15.706806
# post_secondary_enrollment_female       30   15.706806
# homicide_rate                          23   12.041885
# secondary_school_enrollment_male       12    6.282723
# secondary_school_enrollment_female     12    6.282723
# refugees                               12    6.282723
# employment_services                     9    4.712042
# employment_agriculture                  9    4.712042
# employment_industry                     9    4.712042
# tourists                                8    4.188482
# unemployment                            7    3.664921
# primary_school_enrollment_male          6    3.141361
# primary_school_enrollment_female        6    3.141361
# infant_mortality                        6    3.141361
# imports                                 4    2.094241
# exports                                 4    2.094241
# fertility                               4    2.094241
# life_expectancy_female                  4    2.094241
# life_expectancy_male                    4    2.094241
# forested_area                           3    1.570681
# internet_users                          1    0.523560
# surface_area                            1    0.523560
# iso2                                    1    0.523560
# sex_ratio                               0    0.000000
# population                              0    0.000000
# pop_growth                              0    0.000000
# urban_population                        0    0.000000
# pop_density                             0    0.000000
# name                                    0    0.000000
# threatened_species                      0    0.000000
# gdp_growth                              0    0.000000
# gdp_per_capita                          0    0.000000
# gdp                                     0    0.000000
# currency                                0    0.000000
# region                                  0    0.000000
# capital                                 0    0.000000
# urban_population_growth                 0    0.000000

# %% [markdown]
# # FILL VALUES

# %%
# Calculate the median CO2 emissions for each region
region_median_co2 = data.groupby('region')['co2_emissions'].median().reset_index()
region_median_co2.rename(columns={'co2_emissions': 'region_median'}, inplace=True)

# Merge the region median with the original data
data_with_median = data.merge(region_median_co2, on='region', how='left')

data_with_median['comparison'] = data_with_median['co2_emissions'] - data_with_median['region_median']

# Select relevant columns
subset_co2 = data_with_median[['name', 'region', 'co2_emissions', 'region_median', 'comparison']]

# Sort by region
sort_co2 = subset_co2.sort_values(by='region')

# Display top 30 rows
sort_co2
# Out:
#                       name          region  co2_emissions  region_median  \
# 144  Saint Kitts And Nevis       Caribbean            NaN           18.0
# 14                Barbados       Caribbean            NaN           18.0
# 174    Trinidad And Tobago       Caribbean           18.0           18.0
# 11                 Bahamas       Caribbean            NaN           18.0
# 72                   Haiti       Caribbean            3.3           18.0
# ..                     ...             ...            ...            ...
# 64                 Germany  Western Europe          718.8           90.4
# 60                  France  Western Europe          306.1           90.4
# 124            Netherlands  Western Europe          155.6           90.4
# 16                 Belgium  Western Europe           90.4           90.4
# 167            Switzerland  Western Europe           37.1           90.4
#
#      comparison
# 144         NaN
# 14          NaN
# 174         0.0
# 11          NaN
# 72        -14.7
# ..          ...
# 64        628.4
# 60        215.7
# 124        65.2
# 16          0.0
# 167       -53.3
#
# [191 rows x 5 columns]

# %%
# Fill NaN values in the 'co2_emissions' column with the median per region
data2=data
data2['co2_emissions_filled'] = data2.groupby('region')['co2_emissions'].transform(lambda x: x.fillna(x.median()))
data2[['name', 'region', 'co2_emissions','co2_emissions_filled']]
# Out:
#                                   name              region  co2_emissions  \
# 0                          Afghanistan       Southern Asia            NaN
# 1                              Albania     Southern Europe            4.3
# 2                              Algeria     Northern Africa          130.5
# 3                              Andorra     Southern Europe            NaN
# 4                               Angola       Middle Africa           18.0
# ..                                 ...                 ...            ...
# 199  Venezuela, Bolivarian Republic Of       South America          113.7
# 200                           Viet Nam  South-Eastern Asia          191.2
# 201                              Yemen        Western Asia            8.9
# 202                             Zambia      Eastern Africa            6.0
# 203                           Zimbabwe      Eastern Africa            9.7
#
#      co2_emissions_filled
# 0                  130.85
# 1                    4.30
# 2                  130.50
# 3                   19.25
# 4                   18.00
# ..                    ...
# 199                113.70
# 200                191.20
# 201                  8.90
# 202                  6.00
# 203                  9.70
#
# [191 rows x 4 columns]

# %%
data2[data2['co2_emissions_filled'].isnull()][['name', 'region', 'co2_emissions', 'co2_emissions_filled']]
# Out:
#                                 name      region  co2_emissions  \
# 68                              Fiji   Melanesia            NaN
# 99                          Kiribati  Micronesia            NaN
# 119                 Marshall Islands  Micronesia            NaN
# 123  Micronesia, Federated States Of  Micronesia            NaN
# 132                            Nauru  Micronesia            NaN
# 143                            Palau  Micronesia            NaN
# 145                 Papua New Guinea   Melanesia            NaN
# 158                            Samoa   Polynesia            NaN
# 169                  Solomon Islands   Melanesia            NaN
# 184                            Tonga   Polynesia            NaN
# 189                           Tuvalu   Polynesia            NaN
# 197                          Vanuatu   Melanesia            NaN
#
#      co2_emissions_filled
# 68                    NaN
# 99                    NaN
# 119                   NaN
# 123                   NaN
# 132                   NaN
# 143                   NaN
# 145                   NaN
# 158                   NaN
# 169                   NaN
# 184                   NaN
# 189                   NaN
# 197                   NaN

# %% [markdown]
# ## Dropping 12 rows with co2_emissions_filled = NaN

# %%
data2.dropna(subset=['co2_emissions_filled'], inplace=True)

# %%
numerical_columns_with_nulls = data2.select_dtypes(include=['number']).isnull().sum()
numerical_columns_with_nulls = numerical_columns_with_nulls[numerical_columns_with_nulls > 0]

print(numerical_columns_with_nulls)
# Out:
# life_expectancy_female                 4
# life_expectancy_male                   4
# fertility                              4
# infant_mortality                       6
# imports                                3
# exports                                3
# unemployment                           6
# employment_industry                    6
# employment_agriculture                 6
# employment_services                    6
# tourists                               7
# surface_area                           1
# forested_area                          3
# homicide_rate                         19
# refugees                               9
# primary_school_enrollment_female       6
# primary_school_enrollment_male         6
# secondary_school_enrollment_female    12
# secondary_school_enrollment_male      12
# post_secondary_enrollment_female      21
# post_secondary_enrollment_male        21
# co2_emissions                         43
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# List of numerical columns to impute
numeric_columns = data.select_dtypes(include='number').columns

# Loop through each numeric column and fill NaN values with the region median
for col in numeric_columns:
    
    data[col] = data.groupby('region')[col].transform(lambda x: x.fillna(x.median()))


data.head()
# Out:
#   iso2         name           capital           region  \
# 0   AF  Afghanistan             Kabul    Southern Asia
# 1   AL      Albania            Tirana  Southern Europe
# 2   DZ      Algeria           Algiers  Northern Africa
# 3   AD      Andorra  Andorra La Vella  Southern Europe
# 4   AO       Angola            Luanda    Middle Africa
#
#                                     currency       gdp  gdp_per_capita  \
# 0         {'code': 'AFN', 'name': 'Afghani'}   20514.0           551.9
# 1             {'code': 'ALL', 'name': 'Lek'}   15059.0          5223.8
# 2  {'code': 'DZD', 'name': 'Algerian Dinar'}  173757.0          4114.7
# 3            {'code': 'EUR', 'name': 'Euro'}    3238.0         42051.6
# 4          {'code': 'AOA', 'name': 'Kwanza'}  105902.0          3437.3
#
#    gdp_growth  life_expectancy_female  life_expectancy_male  ...  refugees  \
# 0        -1.7                    65.8                  62.8  ...    2826.4
# 1         4.1                    80.1                  76.7  ...       4.3
# 2         1.4                    77.8                  75.4  ...      99.5
# 3         1.6                    83.8                  78.2  ...      15.6
# 4        -1.2                    63.4                  57.8  ...      70.1
#
#    threatened_species  primary_school_enrollment_female  \
# 0                40.0                             82.90
# 1               142.0                            109.10
# 2               155.0                            107.30
# 3                15.0                            100.45
# 4               171.0                            105.90
#
#    primary_school_enrollment_male  secondary_school_enrollment_female  \
# 0                          124.20                               40.00
# 1                          105.20                               95.70
# 2                          112.40                              101.50
# 3                          101.15                              101.15
# 4                          121.10                               39.70
#
#    secondary_school_enrollment_male  post_secondary_enrollment_female  \
# 0                             70.10                               4.9
# 1                             95.20                              67.6
# 2                             97.80                              64.4
# 3                             99.35                              69.6
# 4                             61.80                               8.5
#
#    post_secondary_enrollment_male  co2_emissions  co2_emissions_filled
# 0                           14.20         130.85                130.85
# 1                           43.00           4.30                  4.30
# 2                           38.80         130.50                130.50
# 3                           54.85          19.25                 19.25
# 4                           10.20          18.00                 18.00
#
# [5 rows x 39 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 0 to 203
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso2                                178 non-null    object
#  1   name                                179 non-null    object
#  2   capital                             179 non-null    object
#  3   region                              179 non-null    object
#  4   currency                            179 non-null    object
#  5   gdp                                 179 non-null    float64
#  6   gdp_per_capita                      179 non-null    float64
#  7   gdp_growth                          179 non-null    float64
#  8   life_expectancy_female              179 non-null    float64
#  9   life_expectancy_male                179 non-null    float64
#  10  fertility                           179 non-null    float64
#  11  infant_mortality                    179 non-null    float64
#  12  sex_ratio                           179 non-null    float64
#  13  population                          179 non-null    float64
#  14  pop_growth                          179 non-null    float64
#  15  pop_density                         179 non-null    float64
#  16  urban_population                    179 non-null    float64
#  17  urban_population_growth             179 non-null    float64
#  18  imports                             179 non-null    float64
#  19  exports                             179 non-null    float64
#  20  unemployment                        179 non-null    float64
#  21  employment_industry                 179 non-null    float64
#  22  employment_agriculture              179 non-null    float64
#  23  employment_services                 179 non-null    float64
#  24  tourists                            179 non-null    float64
#  25  surface_area                        179 non-null    float64
#  26  forested_area                       179 non-null    float64
#  27  internet_users                      179 non-null    float64
#  28  homicide_rate                       179 non-null    float64
#  29  refugees                            179 non-null    float64
#  30  threatened_species                  179 non-null    float64
#  31  primary_school_enrollment_female    179 non-null    float64
#  32  primary_school_enrollment_male      179 non-null    float64
#  33  secondary_school_enrollment_female  179 non-null    float64
#  34  secondary_school_enrollment_male    179 non-null    float64
#  35  post_secondary_enrollment_female    179 non-null    float64
#  36  post_secondary_enrollment_male      179 non-null    float64
#  37  co2_emissions                       179 non-null    float64
#  38  co2_emissions_filled                179 non-null    float64
# dtypes: float64(34), object(5)
# memory usage: 55.9+ KB

# %%
data.drop(['co2_emissions_filled'], axis=1, inplace=True)
data.shape
# Out:
# (179, 38)

# %%
#Resetting the index after all the data cleaning.
data.reset_index(drop=True, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso2                                178 non-null    object
#  1   name                                179 non-null    object
#  2   capital                             179 non-null    object
#  3   region                              179 non-null    object
#  4   currency                            179 non-null    object
#  5   gdp                                 179 non-null    float64
#  6   gdp_per_capita                      179 non-null    float64
#  7   gdp_growth                          179 non-null    float64
#  8   life_expectancy_female              179 non-null    float64
#  9   life_expectancy_male                179 non-null    float64
#  10  fertility                           179 non-null    float64
#  11  infant_mortality                    179 non-null    float64
#  12  sex_ratio                           179 non-null    float64
#  13  population                          179 non-null    float64
#  14  pop_growth                          179 non-null    float64
#  15  pop_density                         179 non-null    float64
#  16  urban_population                    179 non-null    float64
#  17  urban_population_growth             179 non-null    float64
#  18  imports                             179 non-null    float64
#  19  exports                             179 non-null    float64
#  20  unemployment                        179 non-null    float64
#  21  employment_industry                 179 non-null    float64
#  22  employment_agriculture              179 non-null    float64
#  23  employment_services                 179 non-null    float64
#  24  tourists                            179 non-null    float64
#  25  surface_area                        179 non-null    float64
#  26  forested_area                       179 non-null    float64
#  27  internet_users                      179 non-null    float64
#  28  homicide_rate                       179 non-null    float64
#  29  refugees                            179 non-null    float64
#  30  threatened_species                  179 non-null    float64
#  31  primary_school_enrollment_female    179 non-null    float64
#  32  primary_school_enrollment_male      179 non-null    float64
#  33  secondary_school_enrollment_female  179 non-null    float64
#  34  secondary_school_enrollment_male    179 non-null    float64
#  35  post_secondary_enrollment_female    179 non-null    float64
#  36  post_secondary_enrollment_male      179 non-null    float64
#  37  co2_emissions                       179 non-null    float64
# dtypes: float64(33), object(5)
# memory usage: 53.3+ KB

# %% [markdown]
# # OUTLIERS

# %%
numeric_col = data.select_dtypes(include = 'number')
print(numeric_col.columns)
# Out:
# Index(['gdp', 'gdp_per_capita', 'gdp_growth', 'life_expectancy_female',
#        'life_expectancy_male', 'fertility', 'infant_mortality', 'sex_ratio',
#        'population', 'pop_growth', 'pop_density', 'urban_population',
#        'urban_population_growth', 'imports', 'exports', 'unemployment',
#        'employment_industry', 'employment_agriculture', 'employment_services',
#        'tourists', 'surface_area', 'forested_area', 'internet_users',
#        'homicide_rate', 'refugees', 'threatened_species',
#        'primary_school_enrollment_female', 'primary_school_enrollment_male',
#        'secondary_school_enrollment_female',
#        'secondary_school_enrollment_male', 'post_secondary_enrollment_female',
#        'post_secondary_enrollment_male', 'co2_emissions'],
#       dtype='object')

# %%
d = data.select_dtypes(include='number')
maximum_value = d.max() 
minimum_value = d.min()
range_column = pd.DataFrame({
    
    'Maximum_value': maximum_value,
    'Minimun_value': minimum_value,
    'Range': maximum_value - minimum_value
})

range_column
# Out:
#                                     Maximum_value  Minimun_value       Range
# gdp                                    20580223.0          411.0  20579812.0
# gdp_per_capita                           185835.0           99.6    185735.4
# gdp_growth                                   17.9          -18.0        35.9
# life_expectancy_female                       87.5           54.8        32.7
# life_expectancy_male                         81.7           50.4        31.3
# fertility                                     7.0            1.1         5.9
# infant_mortality                             81.9            1.3        80.6
# sex_ratio                                   302.4           84.5       217.9
# population                              1439324.0           34.0   1439290.0
# pop_growth                                    4.3           -1.5         5.8
# pop_density                               26373.8            2.1     26371.7
# urban_population                            100.0           13.4        86.6
# urban_population_growth                       8.0           -3.6        11.6
# imports                                 2567490.0           89.0   2567401.0
# exports                                 2491820.0           14.0   2491806.0
# unemployment                                 28.5            0.1        28.4
# employment_industry                          54.4            1.4        53.0
# employment_agriculture                       92.0            0.1        91.9
# employment_services                          87.5            6.5        81.0
# tourists                                  89322.0            8.0     89314.0
# surface_area                           17098246.0            2.0  17098244.0
# forested_area                                98.3            0.0        98.3
# internet_users                               99.7            0.0        99.7
# homicide_rate                                52.0            0.0        52.0
# refugees                                   9717.2            0.0      9717.2
# threatened_species                         2910.0            2.0      2908.0
# primary_school_enrollment_female            143.5           16.6       126.9
# primary_school_enrollment_male              142.1           30.1       112.0
# secondary_school_enrollment_female          167.8            3.7       164.1
# secondary_school_enrollment_male            159.0            8.1       150.9
# post_secondary_enrollment_female            137.0            0.6       136.4
# post_secondary_enrollment_male              136.2            1.0       135.2
# co2_emissions                              9257.9            0.6      9257.3

# %%
# first column with huge range is population, however there a number of small countries
# with population even less than a 1000. So these outliers are meaningfull
data[data['population'] <= 1000][['name','population']].sort_values(by= 'population').head(6)
# Out:
#                       name  population
# 140             San Marino        34.0
# 111                 Monaco        39.0
# 98           Liechtenstein        39.0
# 137  Saint Kitts And Nevis        57.0
# 47                Dominica        75.0
# 3                  Andorra        77.0

# %%
# Surface area of a value as small as '2' doesnt make any sence

data[data['surface_area'] <= 100][['name','surface_area']]

# I googled this and turns out Monaco has a total surface area of 2.08 squared kms. 
# Again not an outlier to be discarded
# Out:
#            name  surface_area
# 111      Monaco           2.0
# 140  San Marino          61.0

# %%
# since having box plots for all the columns together is not visibly viable, 
# i am breaking that into sets of 4 or 5 columns

col_sets = [['gdp'], ['gdp_per_capita'], ['gdp_growth'],
            [ 'fertility'],['infant_mortality'], ['sex_ratio'],
            ['population'], 
            ['pop_growth'], ['pop_density'],
            ['urban_population'], ['urban_population_growth'],
            ['imports', 'exports'], ['unemployment','employment_industry', 'employment_agriculture', 'employment_services'],
            ['tourists'], ['surface_area'], ['forested_area', 'internet_users','homicide_rate'], 
            ['refugees', 'threatened_species'],    
           ]

for cols in col_sets:
    plt.figure(figsize=(10,6))
    data[cols].boxplot()
    #plt.title()
    plt.xticks(rotation = 45)
    plt.show()

# %%
plt.figure(figsize=(10, 16))
plt.title('Surface Area by Region')
sns.boxplot(data = data, x='region', y='surface_area', palette='Set3')
plt.xticks(rotation=45)
plt.ylabel('Surface Area')
# Out:
# Text(0, 0.5, 'Surface Area')

# %% [markdown]
# **A lot of the columns tend to have outliers in large numbers but the outliers dio hold information for countries ranging in all sorts of ways. I believe these values cannot be removed/deleted as they hold important information, and are not mistakes.**

# %%
# Final check for missing data after dropping and filling all the NA
missing3 = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing3.columns=['Count', 'Percentage']
missing3.sort_values(by='Count', ascending = False)
# Out:
#                                     Count  Percentage
# iso2                                    1    0.558659
# homicide_rate                           0    0.000000
# employment_industry                     0    0.000000
# employment_agriculture                  0    0.000000
# employment_services                     0    0.000000
# tourists                                0    0.000000
# surface_area                            0    0.000000
# forested_area                           0    0.000000
# internet_users                          0    0.000000
# refugees                                0    0.000000
# name                                    0    0.000000
# threatened_species                      0    0.000000
# primary_school_enrollment_female        0    0.000000
# primary_school_enrollment_male          0    0.000000
# secondary_school_enrollment_female      0    0.000000
# secondary_school_enrollment_male        0    0.000000
# post_secondary_enrollment_female        0    0.000000
# post_secondary_enrollment_male          0    0.000000
# unemployment                            0    0.000000
# exports                                 0    0.000000
# imports                                 0    0.000000
# urban_population_growth                 0    0.000000
# capital                                 0    0.000000
# region                                  0    0.000000
# currency                                0    0.000000
# gdp                                     0    0.000000
# gdp_per_capita                          0    0.000000
# gdp_growth                              0    0.000000
# life_expectancy_female                  0    0.000000
# life_expectancy_male                    0    0.000000
# fertility                               0    0.000000
# infant_mortality                        0    0.000000
# sex_ratio                               0    0.000000
# population                              0    0.000000
# pop_growth                              0    0.000000
# pop_density                             0    0.000000
# urban_population                        0    0.000000
# co2_emissions                           0    0.000000

# %%
data.to_csv('country_data_wrn')
